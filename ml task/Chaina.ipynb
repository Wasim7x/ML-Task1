# %% [markdown]
# 'CHAINA'

# %% [markdown]
# 1.GDP

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('chainaGdp.csv')

# %%
df = df.iloc[ ::-1].reset_index(drop=True) # it reverese the row and re_index
df.head(3)
# Out:
#    Unnamed: 0  Beijing  Tianjin   Hebei  Shanxi  Inner Mongolia  Liaoning  \
# 0        1992    710.2    411.0  1278.5   551.1           421.7    1473.0
# 1        1993    888.9    538.9  1620.8   680.4           537.8    2010.8
# 2        1994   1149.8    732.9  2114.5   826.7           695.1    2461.8
#
#    Jilin  Heilongjiang  Shanghai  ...  Chongqing  Sichuan  Guizhou  Yunnan  \
# 0  558.1         857.4    1114.3  ...      462.5   1177.3    339.9   618.7
# 1  718.6        1075.3    1519.2  ...      611.1   1486.1    417.7   783.3
# 2  937.7        1448.1    1990.9  ...      838.1   2001.4    524.5   983.8
#
#    Tibet  Shaanxi  Gansu  Qinghai  Ningxia  Xinjiang
# 0   33.3    531.6  317.8     87.5     83.1     402.3
# 1   37.4    678.2  372.2    109.7    104.5     495.3
# 2   46.0    839.0  453.6    138.4    136.3     662.3
#
# [3 rows x 32 columns]

# %%
df1 = df.loc[:, df.columns != 'Year'] #df1 contain gdp data excluid year

# %%
df['Mean_GDP'] = df1.mean(axis=1) #find the mean value of gdp data across there year
df.head(3)
# Out:
#    Unnamed: 0  Beijing  Tianjin   Hebei  Shanxi  Inner Mongolia  Liaoning  \
# 0        1992    710.2    411.0  1278.5   551.1           421.7    1473.0
# 1        1993    888.9    538.9  1620.8   680.4           537.8    2010.8
# 2        1994   1149.8    732.9  2114.5   826.7           695.1    2461.8
#
#    Jilin  Heilongjiang  Shanghai  ...  Sichuan  Guizhou  Yunnan  Tibet  \
# 0  558.1         857.4    1114.3  ...   1177.3    339.9   618.7   33.3
# 1  718.6        1075.3    1519.2  ...   1486.1    417.7   783.3   37.4
# 2  937.7        1448.1    1990.9  ...   2001.4    524.5   983.8   46.0
#
#    Shaanxi  Gansu  Qinghai  Ningxia  Xinjiang     Mean_GDP
# 0    531.6  317.8     87.5     83.1     402.3   873.375000
# 1    678.2  372.2    109.7    104.5     495.3  1128.640625
# 2    839.0  453.6    138.4    136.3     662.3  1476.706250
#
# [3 rows x 33 columns]

# %%
df = df.rename(columns={'Unnamed: 0': 'Year'})
df.head(3)
# Out:
#    Year  Beijing  Tianjin   Hebei  Shanxi  Inner Mongolia  Liaoning  Jilin  \
# 0  1992    710.2    411.0  1278.5   551.1           421.7    1473.0  558.1
# 1  1993    888.9    538.9  1620.8   680.4           537.8    2010.8  718.6
# 2  1994   1149.8    732.9  2114.5   826.7           695.1    2461.8  937.7
#
#    Heilongjiang  Shanghai  ...  Sichuan  Guizhou  Yunnan  Tibet  Shaanxi  \
# 0         857.4    1114.3  ...   1177.3    339.9   618.7   33.3    531.6
# 1        1075.3    1519.2  ...   1486.1    417.7   783.3   37.4    678.2
# 2        1448.1    1990.9  ...   2001.4    524.5   983.8   46.0    839.0
#
#    Gansu  Qinghai  Ningxia  Xinjiang     Mean_GDP
# 0  317.8     87.5     83.1     402.3   873.375000
# 1  372.2    109.7    104.5     495.3  1128.640625
# 2  453.6    138.4    136.3     662.3  1476.706250
#
# [3 rows x 33 columns]

# %% [markdown]
# 2.CO2 EMISSION

# %%
df = pd.read_csv('co2.csv', encoding='latin1')
df.head(3)
# Out:
#        Country Code Calling Code  Year  CO2 emission (Tons)  Population(2022)  \
# 0  Afghanistan   AF           93  1750                  0.0        41128771.0
# 1  Afghanistan   AF           93  1751                  0.0        41128771.0
# 2  Afghanistan   AF           93  1752                  0.0        41128771.0
#
#        Area % of World Density(km2)
# 0  652230.0      0.40%     63/kmï¿½
# 1  652230.0      0.40%     63/kmï¿½
# 2  652230.0      0.40%     63/kmï¿½

# %%
df['co2 emition per person(tons)']=df['CO2 emission (Tons)']/df['Population(2022)']
df['co2 emition per person(tons)']
# Out:
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
#            ...
# 59615    45.125172
# 59616    45.712263
# 59617    46.438609
# 59618    47.109487
# 59619    47.754769
# Name: co2 emition per person(tons), Length: 59620, dtype: float64

# %%
df2 = df.groupby('Year').agg({"co2 emition per person(tons)": "median"}).reset_index()
df3 = df[df['Country'] == 'China'].groupby('Year').agg({"co2 emition per person(tons)": "median"})
df2_filtered = df2[df2['Year'] > 1900]
df2_filtered
# Out:
#      Year  co2 emition per person(tons)
# 151  1901                      0.000000
# 152  1902                      0.000000
# 153  1903                      0.000000
# 154  1904                      0.000000
# 155  1905                      0.000000
# ..    ...                           ...
# 266  2016                     86.441813
# 267  2017                     90.774082
# 268  2018                     94.946896
# 269  2019                     98.985236
# 270  2020                    102.435041
#
# [120 rows x 2 columns]

# %%
df3
# Out:
#       co2 emition per person(tons)
# Year
# 1750                      0.000000
# 1751                      0.000000
# 1752                      0.000000
# 1753                      0.000000
# 1754                      0.000000
# ...                            ...
# 2016                    136.055630
# 2017                    143.068807
# 2018                    150.081984
# 2019                    157.796478
# 2020                    165.510973
#
# [271 rows x 1 columns]

# %%
df3_filtered = df3[df3['Year'] > 1900]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\wasim\anaconda3\envs\iNeuron\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df3_filtered = df3[df3['Year'] > 1900]
#
# File c:\Users\wasim\anaconda3\envs\iNeuron\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\wasim\anaconda3\envs\iNeuron\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Year'

# %%
plt.plot(df['Year'], df['Mean_GDP'], label='GDP', color='g')
plt.xlabel("Year")
plt.ylabel('Mean_GDP')
plt.title('GDP')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\wasim\anaconda3\envs\iNeuron\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mean_GDP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 plt.plot(df['Year'], df['Mean_GDP'], label='GDP', color='g')
#       2 plt.xlabel("Year")
#       3 plt.ylabel('Mean_GDP')
#
# File c:\Users\wasim\anaconda3\envs\iNeuron\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\wasim\anaconda3\envs\iNeuron\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Mean_GDP'
