# %% [markdown]
# Temperature

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('temperature.csv')
df
# Out:
# C:\Users\wasim\AppData\Local\Temp\ipykernel_8340\1808531050.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('temperature.csv')
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# ...

# %%
df = df[['Region','Country','Year','AvgTemperature']]
df.head
# Out:
# <bound method NDFrame.head of                 Region  Country  Year  AvgTemperature
# 0               Africa  Algeria  1995            64.2
# 1               Africa  Algeria  1995            49.4
# 2               Africa  Algeria  1995            48.8
# 3               Africa  Algeria  1995            46.4
# 4               Africa  Algeria  1995            47.9
# ...                ...      ...   ...             ...
# 2906322  North America       US  2013            82.4
# 2906323  North America       US  2013            81.6
# 2906324  North America       US  2013            84.2
# 2906325  North America       US  2013            83.8
# 2906326  North America       US  2013            83.6
#
# [2906327 rows x 4 columns]>

# %% [markdown]
# world avg temp

# %%
df1 = df[['Year','AvgTemperature']]

# %%
df1 = df1.groupby('Year')['AvgTemperature'].median().reset_index()
df1
# Out:
#     Year  AvgTemperature
# 0    200           -99.0
# 1    201           -99.0
# 2   1995            60.4
# 3   1996            60.4
# 4   1997            60.5
# 5   1998            61.0
# 6   1999            61.3
# 7   2000            61.1
# 8   2001            62.2
# 9   2002            61.4
# 10  2003            61.9
# 11  2004            62.1
# 12  2005            62.7
# 13  2006            62.7
# 14  2007            63.6
# 15  2008            62.3
# 16  2009            62.8
# 17  2010            63.0
# 18  2011            63.2
# 19  2012            64.1
# 20  2013            63.4
# 21  2014            63.3
# 22  2015            64.8
# 23  2016            64.8
# 24  2017            64.8
# 25  2018            64.9
# 26  2019            63.9
# 27  2020            53.0

# %%
df1 = df1.drop([0,1])
df1['Change_Temp'] = df1['AvgTemperature'] - df1['AvgTemperature'].iloc[0]
df1
# Out:
#     Year  AvgTemperature  Change_Temp
# 2   1995            60.4          0.0
# 3   1996            60.4          0.0
# 4   1997            60.5          0.1
# 5   1998            61.0          0.6
# 6   1999            61.3          0.9
# 7   2000            61.1          0.7
# 8   2001            62.2          1.8
# 9   2002            61.4          1.0
# 10  2003            61.9          1.5
# 11  2004            62.1          1.7
# 12  2005            62.7          2.3
# 13  2006            62.7          2.3
# 14  2007            63.6          3.2
# 15  2008            62.3          1.9
# 16  2009            62.8          2.4
# 17  2010            63.0          2.6
# 18  2011            63.2          2.8
# 19  2012            64.1          3.7
# 20  2013            63.4          3.0
# 21  2014            63.3          2.9
# 22  2015            64.8          4.4
# 23  2016            64.8          4.4
# 24  2017            64.8          4.4
# 25  2018            64.9          4.5
# ...

# %%
plt.plot(df1['Year'], df1['Change_Temp'], label='CO2', color='g')
plt.xlabel("Year")
plt.ylabel('Change_Temp')
plt.title('Change_Temp')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# CONTINANATE AVG TEMP

# %%
df2 = df[['Region','AvgTemperature']]
df2
# Out:
#                 Region  AvgTemperature
# 0               Africa            64.2
# 1               Africa            49.4
# 2               Africa            48.8
# 3               Africa            46.4
# 4               Africa            47.9
# ...                ...             ...
# 2906322  North America            82.4
# 2906323  North America            81.6
# 2906324  North America            84.2
# 2906325  North America            83.8
# 2906326  North America            83.6
#
# [2906327 rows x 2 columns]

# %%
df2 = df2.groupby('Region')['AvgTemperature'].median().reset_index()
df2
# Out:
#                               Region  AvgTemperature
# 0                             Africa            75.0
# 1                               Asia            74.7
# 2            Australia/South Pacific            62.0
# 3                             Europe            51.9
# 4                        Middle East            73.9
# 5                      North America            58.3
# 6  South/Central America & Carribean            73.9

# %%
plt.bar(df2['Region'],df2['AvgTemperature']) 
plt.xlabel('Region')
plt.ylabel('Average Temperature (°F)')
plt.title('Average Temperature by Region')
plt.xticks(rotation=45 )
plt.show()
